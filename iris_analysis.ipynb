# %%
import pandas as pd

# %%
iris_data_set = pd.read_csv(r"C:\Users\remaq\Downloads\archive\IRIS.csv")

# %%
iris_data_set.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# Shape of dataset
print(f"Dataset shape (rows, columns): {iris_data_set.shape}")
print(f"Number of samples: {iris_data_set.shape[0]}")
print(f"Number of features/columns: {iris_data_set.shape[1]}")
# Out:
# Dataset shape (rows, columns): (150, 5)
# Number of samples: 150
# Number of features/columns: 5

# %%
# Column names
print(f"\nColumn names:")
for i, col in enumerate(iris_data_set.columns, 1):
    print(f"  {i}. {col}")
# Out:
# Column names:
#   1. sepal_length
#   2. sepal_width
#   3. petal_length
#   4. petal_width
#   5. species

# %%
# Data types
print("\nData types of each column:")
for col in iris_data_set.columns:
    dtype = iris_data_set[col].dtype
    print(f"{col:15} → {dtype}")
# Out:
# Data types of each column:
# sepal_length    → float64
# sepal_width     → float64
# petal_length    → float64
# petal_width     → float64
# species         → object
